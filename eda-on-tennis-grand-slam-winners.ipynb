# %% [markdown]
# <a href="https://www.kaggle.com/code/wonduk/eda-on-tennis-grand-slam-winners?scriptVersionId=159641662" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <h1 style="font-family:Times New Roman;"> <center><b>EDA on Tennis Grand Slam Winner </b></center> </h1>
# <p><center style="color:black; font-family : Times New Roman">WONDUK</center></p>

# %% [markdown]
# ![](https://www.tennis.com.au/sa/files/2015/07/Tournament-Banner-1400x600.jpg)

# %% [markdown]
# ***

# %% [markdown]
# <h1 style = 'font-family: Times New Roman'> <b>|</b><i> About Grand Slam</i></h1>
#
# <br>
#
# > <h4 style = 'font-family: Times New Roman'>The Grand Slam tournaments, also referred to as majors, are the world's four most important annual professional tennis tournaments.<br><br> They offer the most ranking points, prize money, public and media attention, the greatest strength and size of field, and the longest matches for men.<br><br>
#     The four Grand Slam tournaments are the <b>Australian Open</b> in January, the <b>French Open</b> from late May to early June, <b>Wimbledon</b> in late June to early July, <br><br>and the <b>US Open</b> in August–September, with each played over two weeks. The Australian and the United States tournaments are played on <u>hard courts</u>,<br><br> the French on <u>clay</u>, and Wimbledon on <u>grass</u>. Wimbledon is the oldest tournament, founded in 1877, followed by the US in 1881, <br><br>the French in 1891, and the Australian in 1905, but it wasn't until 1925 that all four were held as officially sanctioned majors.
#
# <br><br>
#
#
# <h1 style = 'font-family: Times New Roman'> <b>|</b><i> About Dataset</i></h1>
#
# <br>
# 9 columns in the dataset, below is <u>description of features</u>:
#
# *  (1) <b>YEAR</b>: the year when the tournament started
#
#
# *  (2) <b>TOURNAMENT</b>: type of tournament(Wimbledon, u.s.open, French open, Australian open)
#
#
# *  (3) <b>WINNER</b>: Winner's name
#
#
# *  (4) <b>RUNNER UP</b>: Runner-up's name
#
#
# *  (5) <b>WINNER ATP RANKING</b>: winner's atp ranking (>=2007)
#
#
# *  (6) <b>RUNNER UP ATP RANKING</b>: runner up's atp ranking (>=2007)
#
#
# *  (7) <b>WINNER LEFT OR RIGHT HANDED</b>: winner(right or left handed)
#
#
# *  (8) <b>TOURNAMENT SURFACE</b>: surface of tournament
#
#
# *  (9) <b>WINNER PRIZE</b>: winner's prize of each tournament
#
#
# </h4>

# %% [markdown]
# <a id="top"></a>
# <div class="list-group" id="list-tab" role="tablist">
#     <b><h1 style = 'font-family: Times New Roman'> |<i>Table of Contents</i></h1></b>
#
#    * [1. Import Necessary Libraries](#1)
#    * [2. Explore Data Analysis (EDA)](#2)
#     - [2.1. Winner Analysis](#2.1)
#     - [2.2. Prize Analysis](#2.1)

# %% [markdown]
# ***

# %% [markdown]
# <a id="1"></a>
# > <h1 style = 'font-family: Times New Roman'><b> <b style = 'color: blue'>1.</b> Import Necessary Libraries </b></h1>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
df = pd.read_csv('/kaggle/input/mens-tennis-grand-slam-winner-dataset/Mens_Tennis_Grand_Slam_Winner.csv')
df.head()
# Out:
#    YEAR       TOURNAMENT          WINNER           RUNNER-UP  \
# 0  2023  Australian Open  Novak Djokovic  Stefanos Tsitsipas
# 1  2022        U.S. Open  Carlos Alcaraz         Casper Rudd
# 2  2022        Wimbledon  Novak Djokovic        Nick Kyrgios
# 3  2022      French Open    Rafael Nadal         Casper Rudd
# 4  2022  Australian Open    Rafael Nadal     Daniil Medvedev
#
#   WINNER_NATIONALITY  WINNER_ATP_RANKING  RUNNER-UP_ATP_RANKING  \
# 0            Serbian                 1.0                    3.0
# 1            Spanish                 2.0                    5.0
# 2            Serbian                 NaN                   25.0
# 3            Spanish                 5.0                    8.0
# 4            Spanish                 5.0                    2.0
#
#   WINNER_LEFT_OR_RIGHT_HANDED     TOURNAMENT_SURFACE  WINNER_PRIZE
# 0                       right  Plexicushion Prestige     2050000.0
# 1                       right    DecoTurf - outdoors     2600000.0
# ...

# %% [markdown]
# <a id="2"></a>
# > <h1 style = 'font-family: Times New Roman'><b> <b style = 'color: orange'>2.</b> Explore Data Analysis (EDA) </b></h1>

# %% [markdown]
# <a id="2.1"></a>
# > <h2 style = 'font-family: Times New Roman'><b> 2.1. Winner Analysis </b></h2>

# %%
WINNER_RUNNER_merged = pd.merge(df['RUNNER-UP'].value_counts().reset_index(), df['WINNER'].value_counts().reset_index(), on = 'index')
WINNER_RUNNER_merged['Total_Win'] = WINNER_RUNNER_merged['RUNNER-UP'] + WINNER_RUNNER_merged['WINNER']
WINNER_RUNNER_merged = WINNER_RUNNER_merged.sort_values('Total_Win', ascending = False)

win = WINNER_RUNNER_merged.iloc[:10]
win['Total_Win'] = win['Total_Win'].astype(int)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# top 10 total win count

# %%
colors = px.colors.qualitative.T10

fig = go.Figure(data = [
    go.Line(x = win['index'], y = win['RUNNER-UP'], line_color = colors[0], name = "RUNNER-UP"),
    go.Line(x = win['index'], y = win['WINNER'], line_color = colors[1],name="WINNER"),
    go.Line(x = win['index'], y = win['Total_Win'], line_color = colors[2], name='Total_Win')
])

fig.update_layout(
    xaxis_title="Player's Name",
    yaxis_title="Count of Wins",
    font = dict(size=17,family="Franklin Gothic"),
    template = 'ggplot2',
    title = 'Total / Winner / Runner-Up Wins')

fig.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/plotly/graph_objs/_deprecations.py:385: DeprecationWarning: plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
#
#   DeprecationWarning,
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
tournament = df.groupby(['TOURNAMENT','WINNER']).size().reset_index()
tournament = tournament[tournament['WINNER'].isin(win['index'])]

AO = tournament[tournament['TOURNAMENT'] == 'Australian Open'].sort_values(0, ascending = False)
FO = tournament[tournament['TOURNAMENT'] == 'French Open'].sort_values(0, ascending = False)
UO = tournament[tournament['TOURNAMENT'] == 'U.S. Open'].sort_values(0, ascending = False)
WB = tournament[tournament['TOURNAMENT'] == 'Wimbledon'].sort_values(0, ascending = False)

new = pd.concat([AO,FO,UO,WB])


new.columns = ['TOURNAMENT', 'WINNER', 'COUNT']

color = ['blue', 'brown', 'darkblue', 'green']
fig = px.scatter(new, x = 'WINNER', y = 'COUNT', size = 'COUNT', hover_name = 'TOURNAMENT', color = 'TOURNAMENT', 
          color_discrete_sequence=color, template = 'ggplot2')

fig.update_layout(
    xaxis_title="Winner's Name",
    yaxis_title="Wins Count",
    font = dict(size=17,family="Franklin Gothic"),
    template = 'ggplot2',
    title = 'Wins by Each Tournaments')

fig.show()
# Out:
# <div>                            <div id="90dc24e7-1ab5-4a15-abd6-0f04de89b3fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90dc24e7-1ab5-4a15-abd6-0f04de89b3fa")) {                    Plotly.newPlot(                        "90dc24e7-1ab5-4a15-abd6-0f04de89b3fa",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>TOURNAMENT=Australian Open<br>WINNER=%{x}<br>COUNT=%{marker.size}<extra></extra>","hovertext":["Australian Open","Australian Open","Australian Open","Australian Open","Australian Open","Australian Open","Australian Open","Australian Open","Australian Open"],"legendgroup":"Australian Open","marker":{"color":"blue","size":[10,6,4,4,3,2,2,2,1],"sizemode":"area","sizeref":0.035,"symbol":"circle"},"mode":"markers","name":"A
# ...

# %% [markdown]
# <a id="2.2"></a>
# > <h1 style = 'font-family: Times New Roman'><b> 2.2. Prize Analysis </b></h1>

# %%
a = df.groupby('WINNER')['WINNER_PRIZE'].sum().reset_index()
a['name'] = a['WINNER']
b = df.groupby('RUNNER-UP')['WINNER_PRIZE'].sum().reset_index()
b['name'] = b['RUNNER-UP']
prize_df = pd.merge(a, b, on ='name')
prize_df = prize_df[['WINNER', 'WINNER_PRIZE_x', 'WINNER_PRIZE_y']]
prize_df.columns = ['Player', 'TOTAL_WINNER_PRIZE', 'TOTAL_RUNNER_UP_PRIZE']

prize_df['TOTAL_PRIZE'] = prize_df['TOTAL_WINNER_PRIZE'] + prize_df['TOTAL_RUNNER_UP_PRIZE']
prize_df = prize_df.sort_values('TOTAL_PRIZE',ascending = False)

prize = prize_df.iloc[:10].reset_index().drop('index',axis=1)
prize.head()
# Out:
#            Player  TOTAL_WINNER_PRIZE  TOTAL_RUNNER_UP_PRIZE  TOTAL_PRIZE
# 0  Novak Djokovic          53792460.0             21500000.0   75292460.0
# 1    Rafael Nadal          40610000.0             17005000.0   57615000.0
# 2   Roger Federer          28123500.0             17780000.0   45903500.0
# 3     Andy Murray           5500000.0             17880000.0   23380000.0
# 4    Andre Agassi           8798350.0              8054100.0   16852450.0

# %%
fig = go.Figure(data=[
    go.Bar(name='WINNER_PRIZE', 
           x=prize['Player'], y=prize['TOTAL_WINNER_PRIZE'],
           text=prize['TOTAL_WINNER_PRIZE'], 
           marker_color=colors[0]),
    
    go.Bar(name='RUNNER_UP_PRIZE', 
           x=prize['Player'], y=prize['TOTAL_RUNNER_UP_PRIZE'],
           text=prize['TOTAL_RUNNER_UP_PRIZE'], 
           marker_color=colors[1]),
    
    go.Bar(name='TOTAL_PRIZE', 
           x=prize['Player'], y=prize['TOTAL_PRIZE'],
           text=prize['TOTAL_PRIZE'], 
           marker_color=colors[5]),
])

fig.update_layout(xaxis_tickangle=-45, title='Winner & Runner-Up Prizes',
                  font = dict(size=17, family = 'Franklin Gothic'), template = "ggplot2")
fig.show()
# Out:
# <div>                            <div id="aba8421c-45b5-4c06-b37a-a9bb67c9d1ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aba8421c-45b5-4c06-b37a-a9bb67c9d1ef")) {                    Plotly.newPlot(                        "aba8421c-45b5-4c06-b37a-a9bb67c9d1ef",                        [{"marker":{"color":"#4C78A8"},"name":"WINNER_PRIZE","text":[53792460.0,40610000.0,28123500.0,5500000.0,8798350.0,2500000.0,2500000.0,7950000.0,5840000.0,6802500.0],"x":["Novak Djokovic","Rafael Nadal","Roger Federer","Andy Murray","Andre Agassi","Daniil Medvedev","Dominic Thiem","Stan Wawrinka","Sergi Bruguera","Pete Sampras"],"y":[53792460.0,40610000.0,28123500.0,5500000.0,8798350.0,2500000.0,2500000.0,7950000.0,5840000.0,6802500.0],"type":"bar"},{"marker":{"col
# ...

# %%
nationality = df['WINNER_NATIONALITY'].value_counts()[:8]
fig = px.pie(values=nationality.values, 
             names=nationality.index, 
             color_discrete_sequence=px.colors.qualitative.T10,
             title= "Distribution of Winner's Nationality",)
fig.update_traces(textinfo='label+percent+value', textfont_size=18,
                  
                  marker=dict(line=dict(color='#100000', width=0.2)))

fig.data[0].marker.line.width = 2
fig.data[0].marker.line.color='white'
fig.update_layout(font=dict(size=20,family="Franklin Gothic"))
fig.show()
# Out:
# <div>                            <div id="bd6ee4ab-d82a-4726-a86d-6040fbb76cf1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd6ee4ab-d82a-4726-a86d-6040fbb76cf1")) {                    Plotly.newPlot(                        "bd6ee4ab-d82a-4726-a86d-6040fbb76cf1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["American","Australian","Spanish","Swedish","Swiss","Serbian","Czechoslovakia","German"],"legendgroup":"","name":"","showlegend":true,"values":[67,67,33,26,23,22,8,7],"type":"pie","textfont":{"size":18},"marker":{"line":{"color":"white","width":2}},"textinfo":"label+percent+value"}],                        {"template":{"data":{"histogram2dcontour":[
# ...

# %%
total = df.groupby(['YEAR'])['WINNER_PRIZE'].sum()
usopen = df[df['TOURNAMENT']=='U.S. Open'].groupby(['YEAR'])['WINNER_PRIZE'].sum()
frenchopen = df[df['TOURNAMENT']=='French Open'].groupby(['YEAR'])['WINNER_PRIZE'].sum()
wimbledon = df[df['TOURNAMENT']=='Wimbledon'].groupby(['YEAR'])['WINNER_PRIZE'].sum()
australianopen = df[df['TOURNAMENT']=='Australian Open'].groupby(['YEAR'])['WINNER_PRIZE'].sum()

# %%
colors = px.colors.qualitative.T10

fig = go.Figure(data = [
#     go.Line(x = total.index, y = total.values, line_color = colors[0], name = "Total"),
    go.Line(x = usopen.index, y = usopen.values, line_color = colors[1], name = "U.S. Open"),
    go.Line(x = frenchopen.index, y = frenchopen.values, line_color = colors[2], name = "French Open"),
    go.Line(x = wimbledon.index, y = wimbledon.values, line_color = colors[3], name = "Wimbledon Open"),
    go.Line(x = australianopen.index, y = australianopen.values, line_color = colors[4], name = "Australian Open"),
])

fig.update_layout(
    xaxis_title="Year",
    yaxis_title="Prizes",
    font = dict(size=17,family="Franklin Gothic"),
    template = 'ggplot2',
    title = 'Distribution of Prizes of Each Tournaments')

fig.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/plotly/graph_objs/_deprecations.py:385: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
# ...
